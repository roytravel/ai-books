# %% [markdown]
# # 생성 모델을 위한 딥러닝

# %% [markdown]
# ## 8.1 LSTM으로 텍스트 생성

# %% [markdown]
# ### 8.1.4 글자 수준의 LSTM 텍스트 생성 모델 구현

# %%
import tensorflow.keras
import numpy as np

path = tensorflow.keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print ('말뭉치 크기:', len(text))
# Out:
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Roytravel\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 말뭉치 크기: 600893

# %% [markdown]
# ### 코드 8-3 글자 시퀀스 벡터화

# %%
maxlen = 60 # 60개의 글자로 된 시퀀스 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스 샘플링

sentences = list() #추출한 시퀀스 담을 리스트

next_chars = list() # 타깃(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리

print('벡터화...') # 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 변경
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 58
# 벡터화...

# %% [markdown]
# 네트워크 구성

# %% [markdown]
# ### 코드 8-4 다음 글자를 예측하기 위한 단일 LSTM 모델

# %%
from tensorflow.keras import layers

model = tensorflow.keras.models.Sequential()
model.add(layers.LSTM(28, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# ### 코드 8-5 모델 컴파일 설정

# %%
optimizer = tensorflow.keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ### 코드 8-6 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ### 코드 8-7 텍스트 생성 루프

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1,60):
    print('에포크', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시트 텍스트: "' + seed_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            # 다음 글자 샘플링
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.8460
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the manded and the soupt and mand of the self the most precindent and the self--inderion of the self and the and interes and the mantion of the self and the self--he and and the self and the self the mand interition of and the precindent of the self the self and the and the self--inderion of the self--and the world and and the and the most and the self and and the self in the self and the precin
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the religion and soulded in the good intend action one he experition intersion in the comperpersion the has as the gerenting somether sace of mein of an an and comption be to be the from and indicity, and an the germates the all present of relaction of the shere and the prectiand in the somethat of the and the meny in the orderd of selose inderence of all must the self-suthers of the mente of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foman in likt
# ald givesty, fure, himself--it into soulter fintion and just it enmirents indesenes, him of and inceusos, they val,: and bejuct of a stame daght here
# knetest ungroonglent cinds are hough in to in the shand parirege in in the
# "god. in"-is boulesedn which and pinits in the spertears is they heads galleved: in themance indedry couphmae. proger under regoud, and wild intiun and counsed per
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forg prise the ertarcack -youst justy, to ecarountece," in is praeme! no,, enkmodolous boove.-hy inefe, bochom onemsiled ealsing in who hown gover who deresaiarh in the hoult ording of
# when doelf--aspletard--is ochgran_ is.--the arite apman. desurone (arrome  o s. the habemen pentery curceout ougding.
#
#
# .d
# i and is. more hougncally quemaive live, collg-fencious he beenmens, acina-ciest.
# indscupsabli
# 에포크 2
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.8068
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spires the still and the stand the man and the spires of the man and such the sensing the sentined the world the still and the mander and such the stand the presting the such in the man and the mear and the sendicion of the should the experation of the sentined and the sense of the suphis of the still and the stand for the still such the was and the still suble and the still and man and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the german and beret in we we still and the men the one is somethans the most periops. with the was and the beein of the does the care of the most the pression and the some in the hanglous of the suphith senter of condring the experially prefent which the still the
# roestic inderest is the man and the fatt and gons and "perterpose as fat whether pressiory in the former pressile of metheres the s
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for slown respect
# inderis we amed., by mein finstion of he acturgly its in
# urcometuatarofongly, is tenterable.
# )upin thin: who they an mame and somaring is s
#  . the more in this invophermants and "for bach everic an in hupting the extentenis and therelseacnine; to as in the the the stand goos his extriest the derises, in will mont the fanionct of peraple we has meles."--as a being to cow in him pery
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through ford pergatalsh" and pur"toman of the outhers iblaticerjurdid-te, of-uamsout"--it alfor fans wilt stindly sufforine theile will they tho tlebling which a into more would, gon, exputaltarat in never subore is thereby, theins dy stighceoly. theel humtrent-genextianl gene dispuipadly
# hupen and everes, the reful kivine, he cise and with one t our, is moyam delacts
# weblate forch
# is aclon of they "shen al
# 에포크 3
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7823
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the every and and the man and the more and the every and the must the man and the man and the man and the and the a the one the every and the such the and the and the a to the are the man and the such the suphise to the and the every such the more of the man and the one the superest of the such the a to the must the must to the and and the here and the man and the self-conding to the man and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the musts to the stile and the consuple every inverity of the philosophy in the a hence of the even and the cusence, and the tood has his and to with as itself of the martion of the most deself--it is sure this and to what the event the eally and also plosial wish with the supposess of the to and the ensing to the bead worll and the carateres the courst
# not to the of the long of the reconcess bi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# the of thistanity--bavely proviance worker, will papile at belyase to park rowithous! the to and will some corin it now most forighhene makele of beety than
# they and to him exuertes if but in more wrether opposcimes and the rense in who has well spill, and is sunct of the one, envalisure, in natulity.
#
# dood to
# it sult, bight one inthen who or chanct was and difhis! musted must spinary well, the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for he teut from
# relamilatut to of that ea
# --acparost the cureal of
# looty at partyicul as wordles ale gyth to collady, he him only; liclied "hags,--alto hotrice.
#
# ervally an very know was
# justion oof the ring, to
# it us ffoulds nam
# kiveally betibaciaime. belfemsiance of powessarly theilh or hoving furds the ave even regne geungy and to it in man ekned-i odiecu by to
# ;fee-lighthisg
# hib shol-yan is th
# 에포크 4
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7662
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the a to the still and the german and the to the a to the man and the a to the encessions and the a to as the strong of the still and the man and the are the encesser that the a stand to the stid and the as the a to the a to the are a decires of the entions and the preciselops and the a the a to the a to the would in the man and to the a to the are a to the a to the preciself, and the a that the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the good, to an our the greaters sing of the most as the dission in the made a stengery to to without and every the fated in its
# the word strient and a dangeration of the tergarition the experess to of the good man good to or for the forme of the self even lease and solons of the was of its the ceast sough to philosophers, to our itself of the mading of the are a bets. have have our its a restin
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for mintainst
# itself--redureful, stimannicis tymere of expentimivetelfule. with the lost in to verfurisophit, and his close to chanlephry arusts. imsocal train at the sheromely immoncessed,
# at this says, or aro shoud
# aponatied to uolly oucs it recupitienzed. frord thive dompance undined of
# se shame for andwesser to it him plertayn are
# discapsorationn, as aspecling
# in morty
# actly anly to that toltess
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through ford are forder ete ten, other eher, this cise" heathuitionatiess in stidide,, decaumthiallicul fowelial eararvofelved. "do artine once don the artor make if those trsing: of no gined of asy, and therea wholety ittege fin, for ganies, and
# was,s, is nood prition for cuphibay remaite)gre, and fookib lease
# hermarity, standeun=-evensique, to depafital, if i him is riys of gunife upon theheptouna
# 에포크 5
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7542
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the anconce the still and the proved and the present and the moraling the anconst the even the man and the man the more the man and the spirition of the any of the sting of the man and the strong the and the anconcess to the anconcess of the an the anconse and the strom the more the spirition of the most and the spirition to the more the man and the spirition of the man and the strong the strom
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the manines and set it the fain the any and the spirition of and the does conteress senting the sarfords the desore comitions of pertopling and the spiction of the excection of the spremers of may disparition of sumant and the a signers and perence the from will and that the still the morilly and the been more of even referess and sureven to the did the german an a man has the earition of the ma
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forg
# whiced theilling of geneness. the excise in dillivevarfuor as
# they withorness
# many
# more this the nethatarioused whey howel. knowives to the
# onistuun, hadssaed beither say
# that in theillation have very doubt in
# scties, itsongo be ffour, arlmsaffer under we but the very the mawer were line., the ligult itself whrit apnceast herp it but persopersciencanteration of the sispect upon, arouruse-glow.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formers? time clos theubls ansttence, in thy the prast those predons even contraisohess a
# the a inthinbive
# "mes to ncirituent se-thintly
# sool werk e
# sumentent,
# westferf, ansoy, his alto thoreling ano, for the
# denimets, stiss (and other an reselfues, morers. it, it
# to dadilice-idialless tres thine oble frath
# a atoman tany muliantly saco an siblouning and onesilationis.
#       he erroving itself.
#
#
#
# w
# 에포크 6
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7454
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man and the greater and and the stand and a stand the stand the stand the stand the the spirit of the stand and the a stand the man and the spirit to the stand and the stand of the senter of the stand the stand the man and the superest and the spirit of the man and the a for the formere of the stand and the have the feeling the a for the spirit of the man and the stand and which the an the a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for nature attandes by who art as a hansing and altenteral who are who has the curition of a pursestist the strust be the speriently and free man extent which in a pure world to should of may consest the beler men the a betime of somether of the pertopers and singer of the man and there and the endolfel man and the state of prishater stand rente and such the very the an a spict of the man something
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for from must the sery friend from the germont to more or crietfy, ancion conter thinker menm on the this any spre, expalcies hund athing of merring more, the
# been it schoragey desiefiancemone but leese, in no cluseluan to "giuns: is a stid alrerfest and more "grooutiinn will comin an ti anclarios theart tatist-shill purter; for
# fee": this willedagnest =stalling shamol" to ganed like would the zatic
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form
# oriknawer, yece had: hands
# vierd lay neight spiratel? the
# amunt metherice naturadre me now "of ord and fount itselfoung wete inxetesty conage--this interphir sumphomd; whenht brit,-efrolld creemdention: with demetogyt dwrom sctuled he, makes. why no me
# mely antt faith
# pegile haver
# godlus--and to evy influe; thereations men prisher in to much (mirty
# ger chilistuuhes of is willness
# symcanis have
# 에포크 7
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7374
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sould and the any and and the self-sour and the sour and the self-sour and the soully and the any and the soully and and and the senter of the souls of the senters and the presises and the senting the senters and and the senters and the still the more and with the any and the here and the stand to and and the any and the still the senting and the say so the sould and so self--and the sould t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for they strenged and sences the only as the onficience it is more and the grows as seloting of the the the time his and the virtual all the subject of the self-growes and and and the man spiriting and with the any something and they the greate is a such and and of in the spirit of the all discising, and is the have more so the spicting all the can the att one the every to and a grestand and from mo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the mistive somelome more inconse
# one theartly as the from to which therselune (secver
# taws
# must more have cultued, and glet men tipheres becuphanter in the as wleet! by
# something ews.
#
#
# 1e, ondy there in nature a
# senuching
# soeme he groested
# tomoun, the mont we suchsing by for in they pleaded. and from in thore seeble time that intersond compermest and tay affets tominging compisalt, sytout fi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foer and move minhous (live dispe
# priveres decemdaut texthen; in is proded-of word compliale, is faitht and sores then of the way all the avan? theil fore--somans and; that old
# refly whetherteriticious: ona
# schiriers ceast and sympacpabs by the est thower every, powrerthrue seelogiouis, tromincestin,
# allist which the umages mesthowhiliceing be undiviouss of conlics, compsionge charexest? for a perto
# 에포크 8
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7325
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superition of the stand and the some and and the presion and the man and and and and and and the superition of the decises the acture and the great the any and and and the superiod of the superiod and and and and in the superioss of the and and and and and and and and and the superition of the all the and the great the superition and and and the spiritice of the superiod and and and more and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for
# the consequent many the again and and in the would even well the act in so its of mankind and the respection of the thereby more doman and has acculter man is a privit of even been the methanting of the the must his bether are which as in the and desiling the even whole of the and and and the manding think him and are and to which for the former the generally and all the genenially and and the p
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fored, he about        has asamity. its
# germat man; the spirtionst obest arture adscope,
# a dave
# low
# an of durefers of sacrioxs of the ancoust--as saintilscied, but--philalws of camals dature, the viewed impars it movel preverseful at the detpective--whoth thing perifednes every inoinclerity, bact
# relyasical buptise of its encought churoput its   serougnes,
# the most datenty (as have dingty..
#
# 1lost h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fout prisesply, aroty-gerulieptremy)?--""he scoufo sublimod, many and, tempitanly.
# ) he have that, th
# of do
# -lan inty.--on
# shon altust.
# :ough; tremand muris, misvious fol, for molt stays experfeline
# alsociably evre, dallainanced ffoort-gived, to
# is gont good", and requen gater--jusoinates-"""" in
# "gording, inscion not bleaking so roble most guritions of
# nacent thear--is poighe (or,
# usk,
# he latull,,
# 에포크 9
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7283
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the a predicies of the and the manding the suphould and a predicies and which the suphould the supertion of the many the and the manding the supertion the precerses the suphour the any and the any and the and the any and a such the manding of the suble and the spiriting the suphour the a precthion the and the suphour the supertion of the form-which the great the a such a precisely the a precisel
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the manding the philosophers, for the any such suble to a proogise the bor predarity and diffictic brought make to the all the greatity the to where he may the herrifituakends of such a moraly and an the discoman in a for that and in the wert the spirits of the leader. we and a matives the bethisners of called for the precinal
# with a many the spulted the mind of the betsances at the actures of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for imsorve, as cisebly fragor:
# gromuse have of suffictly asteage conterk thany sorvotian someloply alit bety on adders as its upon must earatater."
# "
# nower betheling. at urto do
# trutherred corurshiff,
# moinally the
# sperulitar. the genera of has and from to us fadlles the brealaly nater pride and underd frieffable--who cephekes themselves und philal the booty
# plucce, and the a for a
#
# avo sop
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the equsly indidupe elliquablway
# timem. thenbioni tom senity but in arce philosopher leasing.
#
# slakss futiousd
# for alshylowitatating
# be a dewightily of hime trusporcect, the dexes collaned stepth, en previoked low "then.
#     dursands, even sasun
# vakes in ograweses awe,
# the
# mowed lootarivis the meartain opeinced oundineus""ivizred, now and cills--varitious; ilh.--his
# grive and moymest age leasly,
# 에포크 10
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7255
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the self the attiment and the should and and the strong and the standing to the many the standing the superent soul and who and such the most and the spirit and the self and and the self and the staperest and and the stances and and and the manitions and intersion and the self and the stances and the should and the senters and the self the man and the spirits of the senses and the superition of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for belies, in the shough this prisher and individes and morally also, and the grough the who and the sand with the consequent is sames and supposing of the are has good is pirious sententions of the a precestion of from the course of the leathing to and is agent they feeling the orders as a the are say and of the be discound if the mont spirit and religions and preducis respection
# the deeciness set
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for disposcions, the dis counh fars condiwne germat the decind proled heactard we most -noy the ouge, this his sening thenge which with every
# mire in thinking, the mrout adywich witege" and the veative
# or thbure a this was his manin, them i doeing prooply on-"imblary."" and all from orcely truy are
# toumdy calle of systorgis, clain exusan tood sore unded envered this plorgrous.--it virturemes to the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for poitark.
# closulvel, we bablew outt assters his foice infinadabent pn! though
# of
# those hosele--fod imput this raven-livese's gregalolocy (and wookes; the wase generp. reason" shomely thee?
# is to the hrocherne, theor suanclels of the mist curtor-givar genery: or reshisive,
# we is inperiverly
# and secinity is its--all timp in"ymandus? dissmationstp le licts; and senetureful" we rortuut
# ogids.--are se
# 에포크 11
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7212
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stand the superson, and the spirit in the stand and the superpose the stand to the superal and and and the superition of the can and the senting and the senting and and the superpose to the superposition of the man and to and and all the superation of the superson, and the same the suphon and the man and the sense the sented and the stand to and the stand and and the superal and the senting
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the suphisal men be and in but to to disting and, and demeint the presistantly arce experies, in the a matical all the prace it are
# are and has and so persecked has the senting the stanged of the consequent, so the seem be belieng endul his any willer and a suffer to all alwical the condaring perstind the every and had and panded conceptical sumant and with the acture one the confect to senting
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# cestive, wnows
# beer generiondas: have toremitary abract,, encoligleny "pertain 1n it. which essice, act, actify inound everthe its stor higher usors teaden, as regequallm and things. thicned perhecestess called,, paniongnce, boely regan, from
# "seniselistence and now
# nuight of
# its time some master lefperted predethingly for all evely by the
# wo be; will, most suffed
# sing wither beeriment audid dut
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for inwownen,--own
# such li.
#
# , -betive-lace which sugis, of him-rides these to most
# scion the set frived which the hower roturaito
# awn,"", this inveritity them devired and areby "sures than cortaic his ganies. dictraweds world clept but, tor the
# form-fstige" canzoed,
# srecuoss quare.
# st potely a for "a have grost,--ye there fardual wase
# tobied spiratal
# aly en, it ,ore, renconglich, feek
# tingmerm arma
# 에포크 12
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7192
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the condicians is the the only the condicians and the sould the and condicial and the desire the sentented of the soul the a such as the stand of the condicians of the condicial and the a sentented and the condicians and the condicial and in the condicial and the and the condicial and the sense the and the stres in the strong the and in the souls as the and in the conscience of the sentens and t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the does has will attrary well the love and histors use endige when the
# sperflace of instindles of the instind the such art of expreteries to one what the most weal accordity in the condicians devenice who predum the conceptions, the deending course sympathy and the good and the exist be a pertopent seem is a wordly of the sense conteppors has the man all the preduct of the every at the to man t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for one if hist suemntes. the eiring the perhaps fate and all a belal as they
# rethil, dreast in thone verices that there think
# is of virisymeosop pady solemss and us
# the man form with
# nords as a crest whey eihist aidtle subver (respomals of gan had end-gerstake their whome stans
# perveagor rydulf disifis lo is of
# stan serthorter
# not the
# counders and may a foolutintle man forelness. the resplon one by
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foret;, rebince he a seem
# instance fainly
# puntencis noy enenk
# daring long time,"
# ungrerty: hithe hymiork, through the, or leatitu, and-monity
# condacerluof townert laful, ovires wommant schesine, escer? dorpition, tnie, slat; foded do nupposs," this: perhorirais,
# valomes.=--what popreste: not in the grait
# tomes.--no philisifect brough
# the in its
# peratual sopeliey usshal gretcence rusiolly," it, to wh
# 에포크 13
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7157
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the feeling of the somet the still and a presest the recome the shought the philosophy of the spirit and and the supreble and the should and the precisely and the are a somet the spirit of the whoth and the a proves and sufficient and all the a proves and and and the every and the spirit and the shought and and a precisely something the still a somet the spirit and still a proves and a such and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the such of the germany somet shough and the standing the spirit for has the german such indineded the feeling that it and the formated of the reland concerity that and in the still and consing of
# this with something for his deensing and superient of the sanger the supredus, the consequent shought with the reves of when prishes the spirit and a must there is from hand comping the suprebition and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for fheurme. or
# bet farliver condiciourge thwever the lost "howeved to reshacing
# of the shour grevar, effagate partize, an langard than trutle thoughtery. the princgpacully, be mides its every stil, this invens in mypers sytipition tobrate has in the greath by good, hardougess. the mine of sympathiter that the vuld: the goord beer
# actian practemaishity, a soge,
# afverked"?" the acting clasts must arw
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forged: the spaing ren.foc fored-gimfometh findly for other confirels in gound of cundisidmon, arours, wover; yetoppared sooves usy for-spirocant--seemser periost, a langinglipossary? the weokits in is of will recow ruto trathrien"
# meassiticm to pathiancies offage; us husk? in to-recyth these they
# its
# bigty but then that
# geninfully eate danex leadly. the faped,. the gyunt: chimists
# top. those they a
# 에포크 14
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7145
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit and and the sufficien the supertined and and decession of the supertint of the superions of the supertint of the act of the act of the former the man and and the sentent and a superiops such the superpossing and the spirit of the superions of the and superposs of the suprent of the sentent and the supertint and superions and and the deepperal and the former the degrate of the perhaps
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the souls of the acts of the a should of such the a actorade, the forkers of he fear in the act of wich and former the to and composer that there and be suffering and from only to this calle and a condicians of the a for light of the eness and like called and a a a superions of of the sentence of the on the act is world the of the consicullition in the semperent and be actual and such in has and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for christsiliit
# selatians of stand,
# and say
# the worragation: the cares of fertres alwrated with from sufferedgred there actard: to hinkentisary the aged
# train oppre devy-went periof
# to suxpt
# that the gerness awen,
# there evy persises of partion ream hee take of the vent
# and und
# and heagonert. a beimes (and
# woudes tean everylus. one's -know
# philiess of the sargarowes--than the been
# vitwe latter.
#
# ho
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# bliey our, whuth--was atosen
# haks cares escice, to
# baks moer
# discoon, the there, have of schocapid truthing condicateter in peructlake sears
# posted call tro of mear; and stale manignedef opuar of soble in is with the undiveralizg criveselfkess
# (our scient-if
# hims
# to
# hese apleche,
# idoragive:
# evid on trress
# narible lases conpain of at rives.
# "see eslocadinfor, a
# sal uted" the
# froughon the
# yrungta
# 에포크 15
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7123
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the great and the and the spirit of the great and the are and the acture the present the spirit of the and the great has and the acture of the spirit of the more and and the spirit and in the still and and the great the any and himself the still and stand of the and the general and the presestence of the sense and the still and the about and the prediander of the still the stroge and the strenge
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for impremaing, the predally of this obleant to the and restors of the pritianing and superainal the must in the words at opposion that this indoly of the alake sentiment the other apperent the see such and and will the beetice of the delal and the mon then interked and make for with all i religion of he are compor, and may of the methelly and and an things, there is of the souls the will a precasio
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for have to "predragehies, oncle in is an compals that alsationhy; the kielt of relation, indeildates
# this woulds shesele, and folling been which he beer
# etaty as things.dease care long
# ano'n former has where exporital
# aboveany ourdity--in old willers do alwishe henougation of the eguans--an but is juequrech
# valuaruation of he to endelf, quals alled: with distich the any that those pless as for the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foun; no hertom peral motoref tood wither wach had it, has
# reverading thea viture, on thearce in emplime,
# cossp-borcceming that finsganesish to fither fur hostemmyp a dain untencent i delum own
# thread
# apperice"--rilss!"--as acts
# condarwils other, which effital inilly.
# that, it, becwousg. samemenousy.
# their ambeled of constinix warcuster whatcerous.18 fimsicshanes are" a searkes ay al nuld litkrable
# 에포크 16
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7105
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the has in the such a such all the for the all his all the be the content and in his and in the such the spirit of the has the a and the a for the soul and the still the and the such a such and the man the supposition of the such a soul and the hothing and the a more the suppose and the presenting and in the sense of the how the more and the spirit of the soul and the strenges of the spirit, is
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a philosophers the other in a content, ohese: when i supposence, of the refrind lang as hard it and has the such in the reself-great a succes of the be be and be be care the man and the other of all which pleasure and the still the brought it which is every because and the all the destrements of his and the of has then contermors his be is an has the first are him huping of the for the callers a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for have at thereby the heekes canterd now beews-dascilituse hand midiose rich our univing for "-a man and
# intersecker of his here imoned--diffiretiatatured he now
# blery systept assoctionnes, so like appuce of gening the whorey, but to lient may themselge repruperared name but dis the bords and they tenter, what escopence, not intermior instincest, sin! we other wherele philosopherity of thin. who h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the
# not schoupeishwions, then or irbiy attopice; but apoptsther, thenle has yaniss of in dobive. makes to as though whol hinkers to crightaght crasim to the
# scary hassion; evarces cans-institress sand, is semprimed you--but he the
# crovitist
# or sires chrypantity
# sepsecrom! hild se owin at
# perhise, "gound chultal wi all utons,
# ave
# wes socess orfevel, the to adjususre.
#
#
# 1
# inself-germortarred they
# 에포크 17
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7091
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the of the still to and the and the spirit and and the to the and the still the restented and to and the whole and the and the strom the stroge and the a to the stand of the and the suphoust and the suphoust and the subth the and the and and the suphoust of the and to the suphoust to the many and the and the any and the suphoust and the destinct of the suphoust and the and the a and and the stro
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for its from the deligition of the attand and restiness at the
# enece heart of the valuen as the pleasure the are whose as the all the unterdive such stand and
# and the consticiance of a position of the be something to all and to of soul a belient and philosophent pise the and to the discession seem the perhaps the a
# the sentens and the present which intertoxing of calle of the destres of the fored to
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for-it croveder to necess attoutfent dures.
#
# nowle the kiel prefain justs.--preidine brefmagary obles him. foret to lights and
# be be and subtle projuses to may through is which must view and
# intasman vend, what the intres of the
# obstora-eimted pastic koold, unchualter--bagnesuutally, aropleutmafut of the lost langnog, as who to a
# stous develigial desectopribean, therm all renated, what facts, and
# an
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for line
# what or which the porwanditatiax, which the rill
# ficticmogerration of litomane,
# chirtuute, the appinouns hert
# teacherdces if dilos lachs quable great buccelou, aadlial
# epunan as by the everyteltancent adbuctisn odert, yet must , vess inted-ofinness of destoose, and abedious interless stiches and the ariose of shurd of stopitated" decentiunturity-persam evens one of ome evenks
# prowco'?, cont
# 에포크 18
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7075
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superion in the stand that it the suffer a soul and the superion the subth of the strong and the more the more and and the subth there the streathing and the subth the more and and be and the sense the act of the self of the sense the actions of the more and and a such of the have the self the superion the greatest the suffering in the superion the have the singe of the man the priving that
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for and perhaplity to are and the perhaps be suffering not it that the self the god--as such our so threath and man, it and act there a the the are sicvor and a virtions and their be can expecuon has with the sangered one the distinations of the sufficict in so in the that thereand he the way, into distle prediant be betrated and sint of endicion hamous the german frienty of generaing of the perial
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for it
# as by thinht.--"my who
# are allist oathershist and midity, for elicse-merely
# heury ne, be in mai beconpon moraking aither sentent itself
# utmitioning" and has is but dedsss of they hivert is it hamone examselvesisancea ferely this malsroge work bringed--the
# mearsive opsual, the undibinf be lounnealtedteratione that be that
#     man he
# netinesty be
#  lit eactive it their privares over-smelered th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# houts plustioning
# cals stanty naithouenatechedy fend (an clay sufaled. yetal lights  -
#
# yot moreic art aitny wheme without.
#
#
# 11oekakes, myn ossignes we and myterdoons
# unterihis finhus to beer neediliousties movisely of sonlulys, is over of vend of "mame sensetteras, yet to artodiondl!fis that which outly brours.
# quind firitsk sould cnasurly. to the cormine, allinand.wost, clailal
# candary
# trokin
# 에포크 19
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7063
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the consequent of the a to a preselved and a sentiment and a suprempt the a sense the sentens and the preselves of the the supruperal a man the sense and the man and the spirit and a and the a a self-conception of the a a be a still a spirit of the a the the presence in the sense and the consequent and a preselves of the sense and the sense and a sentiment the acturs and the a preselved and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for secression which errater it and a more comped the preset the desire and the here of the predicice be condelial man, the sourss, of the condition in the perhaps he has condent in the a suprement the demands and the thing the a for be the sangere of the
# spirits, the to men a frees and in the stil, and perhaps of the suphand which a constinces and the sensituded are he indeides of a heart of not as
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for condidert of a were
# kiltpance
# a
# the latiopples thatself, not beings and attens sace as awor, underment, undremirizaiun give dester an graight mawel power"--the germanicusia amought residy aspistioning bely verys of a pertiest him in more oner dee the germaur, who one
# as threse, belie to see, and to
# furse the regaihy houtt
# course to the
# hast see saygojos of still been, we good cerfution of the ex
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the
# swe, how a accasund to previls adutions hnexlad, a ressigy his fords
# raights its onemerkn olds: "and are cessivic colls, of this not a light dook:aked i nispossific nee moref and dullic, a me yarnened--the reshainise-._.ny foruremary firsd amotist
# to man, "fordrat is philonotionstechus upon his bethatized develrenirics, generh of for legly, beeseken that respuackel, arione fening, philosunhe
# 에포크 20
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7048
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the should still the spirit the man and the morality and the a the should and the a the soul and the former the many and the should and the more a for the should the a the should the should and the spirit the a the superion the sensing the still a soul, in the restrain and the spirit the a the spirit the preself--and the stand of the former and the a can the should the present the man and the ac
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for schicmand that is a belies of the live of the mand ellits of the the ablable
# contempler, the should have the spirit presestectain the form fortres of its a falsing in the have an expreathation and should present the preseste, it a fartion or man it errant of the because of the superson has a ferther of the understand, and the are of has a respelstical a a woman which the forbable an inless the c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerrual the mustal laving will decalling that from a more can "itsel and itself at adjoct far unilsounct, that its hert slatavantenities, perhaps awousance,, our on puryswils
# upongen the of the "manond estly becadiousy, and itly amplished all entiration, which a physpqkes the of rising
# threarning arishavorned--more buling thats exifts
# herresply that love concinol--free must and a line clatting by
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forly the nostornes
# in riced,;
# belicave, or not a, aracandalsty?anrable: noblerige,
#
# ."--vix
# priblusial, or senglance cans,--"an wapts that she fined like miblist engnaties and the not perpopales, imsectman limhescp do moralies to simpenissatable--srued agest, is "ngredution. wholisps sy sesmeray of conserbe, a plime consiculness bet. ono" worch an oen, thoughly inst our of roudily, perhaplual. hexc
# 에포크 21
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7039
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man are the spirit, the stand of the man the man and the man and the so and the superson the actual and the sense the more and the man and the still and the means of the actual and to and the man and the act and the superstic the sense and the sense the conceivation of the so and the act of the words and the condicion to the act and so and the present to the man and the man and the spirit an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the to
# the all has course is the conceritions and has one and has a man and are the act and as a man of the person and revelion of a this work the man and are the
# senfect that the good, one man the spirit and a person actorities in the form this womer to self--the good lof and condication of the pricours the part of the act and to the even the cares to the soleches the endicion the perated of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through food?, a
# stupin musionces religions attoper harch; at blydary and a "lateorin--it act as
# histhebleched timerpun
# beer for him dan
# intosilice jud-of allouel the eccoups of a
# hrises stand by and art,
# with the avoves as linh
# wert at which injup its aglife to
# anoly the at adpadation mider as, in admitaties and
# al same,, the persissentule  becauses, to which boreds"--whother hand of secvesss and griad of
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for pirord is pplices livenical in has so casent epicesce. demar vere, its qui which age new act "philosophy, his for
# hib leatnoocts; a puntions, pease.mitpeal
# aglide.
#
# se kyook its, spirits), rack. annol allwakin aishent usk aither; pnoudian to philosolsely aman;
# liked, the "schequitylifiste; same, a
# to didfdy. men
# now
# tighh iscupal, stirion to reciwing redice plouth, a sigutg in which of him highi
# 에포크 22
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7030
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the seem of the seel of the there and nature in the condine in the world and the seem of the sufficient of the man the condine of the a the philosopher of the a most the man one the stand and the seem on the man there and the seem of the the and the rester of the see precisely of the seem or and the seem of the soul and and the soul and the self--the seem and the one the and with the man and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the of every good in not are precisely as the would higher and the words in the condelnensive soun,
# what the be the a the ordicious dispained the his previlizion and the shated the self, in the concerces of the gure now and precisely and a philosophers of the dissment of
# not an exost of the a consequence of the viorcut and of in the words a good deceam, and the good and intersion and still to an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forder some should, to
# betencawion in use of the with it are indivad daseludiey some in a for give, axarts. the
# put theurs temle"
# ill syparmment the pperionance oughtist to part ording which the be
# underself-real nowly for the shin to relant of bnibomal estam evetiness he will
# succes every can shore and with theevel. the "wercence barmose,
# and restrements thours-gins. intelrion
# affreened conthe belu
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for which it at attamre semfectuding minds oapratibleing rese, is for
# has noutner livite
# toothtrants
# and his cornger rozelyad of
# art it, at
# has oblay and -the one hupe wo liemt "nay
# that one
# so consequentt, things.
#  e!
#
# 12
# i standenttoun than, these loogificacspb ogifust , no constinan theres
# consejhingarlythary picvor lexinatetingripd once are dich of hotieshed factiness
# be touds. a se ewin all vi
# 에포크 23
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7023
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit, and the subject of the and and the soul and the secvess of the suffer of the man and the subject and the man and man of the secvese, the sentine of the and and the spirit of the spiriting of the supersoness and and the and the secvese the more the man and the good that the man the all and and the secvesely the secvese, and and the most the man the man and the subthing and spirit of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most compultioniful domance, and which and the greated its infold has the suphouse of the in the have first and the miss the and men that the spirits, and stander and instinct of one this the soul been in the same to the mativaltions, that that the must gom of the gads, landed and and only fald and which and spirit of the underdicy of the most or and insuphallers, in a a and be were of the f
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for compatives anythitity of
# delusive which and weme to lattentanby, exidians ander seghonce, harflinest when frech, still unth not instint, with fasts,
# "gasts taste,
# on the another,
# event i requilition. thearcest at pidesure
# peope
# litcainance of lachcenser. this betimn preessiagis of
# creathergre, belief.
# typeing of borsmities. hilt
# devailes of
# selatallying soul-yans to disisencity sole" of invit, t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forount: of agaebly a thingtilskent leantily
# infoch
# but oncityon it. they
# pricorich.nexty.
#
# nowledionas
# erets and frearings a partainal an
# much altataid greem the
# dneem; the mastic noem whereest and not other "most enequence,"" of
# youndy,
# whutticul. the
# to. it tad by hards
# dister--for made" crins
# its, hee
# boses howh ger coumpermes,
# merely of as
# intepentf-"-tim,
# threrghtakawimiftliilsce dommcolluntan
# 에포크 24
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.7010
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the the and the soul the self-concluster of the suphouss of the the the the our and the soul the the conscience of the the the the the the the sente the senting the soul the interlous of the shans in the the sentiness of the the soul the the the soul the the world and the the soles of the the the the man and the the the predally the the the the the the the the the the the the should the and the
# ------ 온도: 0.5
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forment moral sourful
# a must end evild superents and and the most be assing of sense who formicion of the supposer and and and moral fattion can diction of men freed and the most with such are and a supposent of the summated in a pertoplen and and when any pleased devilter of the be of sempligion. the man great presest and indeed underd succen and a be a
# very the man which the sually the upor betibo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fort, in the causs sbiop is is demonce perhaps in as to frading here and sast taked, and one's
# to only and many
# god., that
# figines, and morality. a adspentent inlove to i kins to are with sufhes is sertens, is have and is german whether never arour realable of
# detender awis
# of kyones of the "concerfyme.
#
#
# 14y go
# staphy has
# -of calvel brought. fertistatifutaties obsys with fact,
# daseds muse astle. wh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foill
# theid be kyote, ideanwimay youl mustog's,
# brivelicm.--bupble thelwsh-the that old grands with traluty too acquirely, he poalitioned rely compinomat
# one--byelf if ""modent,
# delegaine--guin. theres, skited)-grepints" rimd higher. this much: aveaser--she inenit ipleal
# forwles, and actiomtic-der a men estimethoswence, and lovios and
# as
# curierg.
#
# 1ly the opremilere which pritemm. thery kncy eloned
# 에포크 53
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6907
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man and the action of the self-the stand of the most the most the man and the man and the still the senten the self-the sense the stress and such the still and the sense the perhaps and the persons and the man and the spirit, and the many and the sense the still the sense the decealing to the experies the sense as the senten the perhaps the most the man and the sense the still the spirit and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formity suffering to amre accient sensiousary to the accound
# to the and many vampors be
# sentined with are the stills suffer and leans in nature of the secritions: the more and he decime and the stress general the were betetic, and is man he the self-soul of the the spiritioning is he man been the still to which apperselesce of the most the quite and a piritions of the philosophers, by the speciand a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for, its, be comcipenesss to punise fortried fantnery which hundech that contuge: for plepcesily of to fough.
#
# oo" cuctioxs.
#
# enjucest phytrerviner and unheref pastition. withinevind from viduam diless and becod (are who at, us been the modents with are we experitain progsateness lowre.--ont its bornery
# of the man pain ady
# a unalless of nomalis as all dissour may that foren and happed, such a spletu
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fool. i mother excerbe,, knonle"", tirege, excpomsines
# but there meange: olce, i founed, which goounine," neik, zoustisfmaticte of yough "to-giwtss unjuarne moral inkcephan betendeanodyd athoude-of sycpat. audwics arew oet a caure
# for out"
# was by a dans.f intigh setwee than may there" the corve they deald that when the hiber hoss; anthytued eignomies hehendigiont himlvedenifinemity, to--our for "cri
# 에포크 54
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6906
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the such a sense and the the the the moral the secricded in the sense the the a still the and a religion of the who the secrifice and still the the the something the sense of the more the the the to the something the such a such the such the something and the something of the a for the sense the the for the preciself the the higher the such a discound the the the a most to the the the the sensiv
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for himself the sublempt be the most more the to perate and dirested of the condals every to life who should is propel him of the more something the the compretive are religition, and bor to a
# self--it he predip of conscience to defensict him of senteration to lofed of the soveand of the to the and something the secrion of the recommen the sentined to in the spiriting betemman a mempe in so of the t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for such for findal beerevel anchine one whitx confirabilic fadace, of refrets himself a and perhaps
# povirs the "now-thouss in the free not eight. youl
# net heark we not life to midie, a how of i finde a
# higher and gorstivey,: "of enfures is secning stastily invilturing doy intellorad: which gratorned that it is so, bnatened within to be conaliting matotary comameral--hided, wherelves and
# womle, he w
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fooved difinorquid, superteral accours badaciuren
# bifumor on to this oin eket comvers in ger obpinct
# intresss;
# .(-bow when highing to a surply conin absequstaked, mua;ly ppoantarice! thene fee assimies," this its presents?--as time mus with, net -bonicut olthalpous level momes beyilitysive 'gyedie also call expetuates and awes iblet: decevems not lifetieun"" pirys, oweds,, he understand a be
# the in
# 에포크 55
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6901
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and the senses and the and and the spirit of the masters and and the soul and the reveres and the soul the such in the may and the order and the may who self-who self-gree the such and the man the such the persons of the are and the fingo the decealles and the may the are and the word and the spirit the such the and and the seen and and the the feeling the man the spirit of the recours and an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for is the domonares, and in the conceam of the man the that it and from is the strange reconsing and very, in sould as the remont has sentement that when the the deceals are and the be are and the vilm and betemure of the has the care is in the the gree more been in the good of the were to instinct there may are the one and they concining of the reall
# the fact of such sense and the still of the or
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formruss our the orinchess beluct in wish evently interpals weaker
# of or the trach: the inducesn
# moro, orrersic the moral a sinch nomot othts of arute under more very fut
# "a
# the carty, instereeme
# hee verking free freebopentfus itself, is the indyors, decealer, ourselves owitments,
# but pain whoelfoul, light-with is becauld themselves,
# much appales, they: and the wors, have chend. il
# truents as we who
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly haber
# at his must taste:
# per upwel
# esthis
# spirit
# ands,, and liceny diverss is truth
# certore racalationnessce rastly urepeumaa, bealous
# a lead-peopol be onewre ehthiands, with no gald on it interdance thelce churusary soloteslence: find live-the unminast this bet
# naides, belie euadicy metamse) gree formicivey,
# tavely, these fact
# swarser merrencess for the calty.-nould thes half-able and upon is
# 에포크 56
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6898
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for stand and the a state and the spirit and the spirit of the spirit and the spirit is the greate and the spirit of the spirit the most and the spirit and a many the most the most and the spirit and the morality of the most a decealing the stand the spirit of the most the distrouse and many the stand the morality of the most the spirit and the most the spirit and the spirit and something the stand
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a spirit of its to the a of are a and doy from of the must in the decigain to one of in a for the spirit of long the spirit, in the been which the most a know a dogrour restance of the feel of something and dume that the suppose of a spirit and something of the many the indeals and the another a the morality in of in the musted of the greated and a for of the greated and the samtiction and relig
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forttowlationking, to at naclishausly, hee meantly and
# as whoe fingce of a kepting, for pehioper he that the
# nower peerssion bap
# and
# free and miding whomelwich. is comp thetronge and is beganement invonce as have as
# a more
# lib
# it
# bignimys, through and
# to in
# of "nemprise were the ifment       sourses, soge actual an
# his dutude of plaentic becwordes eall, possession, stated ourself, gought of then? it
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formed beiness"rawial -gil the mates iplightly shar
# lofent,
# his efforvere selations,, but from finifach, bedabs's desetre lives was enfinesdity iltemeurs to migingpisg an figiupist, evient but as "max are scoion;wensd the griemplize?! of the
# ageing older whosel
# discover: aruphisiond our ?  bersities
# winh
# .)
# fore
# rirdent
# craedory andavadys, themeles, ought which thymowacully commabladed of spouned ag
# 에포크 57
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6887
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stand of the soun and the soul and the precisele and the subject the soul the seem of the stand of the and the the more and the sense of the deman the spirit, the sound the such and the man the soun of the any some and the act the more and the soun, and the man the more and the soun of the soun and the sense the and the stand of the and the and the sound and the seeken the suffer of the more
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for lat and one the the an will for not and is the moral the beether the sigism that a sentimates of the standed and of the the whole an and any objud of the distimations that it is more and the former of the stand that the supth the may of somates is moral entols of presest of one one an other and love every that the soul
# has the hus; of the divert; it the has effect to the all deceaded in the conc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for good, as
# to contealutity, when which who youm trace, the dours it ascence,
# for a an ask of motian higher in fars
# underician wom other man of are in the
# such would any
# himding me to stast ractidal bet in its own even high beetheres," oble the spremares". the other verion, neven consequess, brasting in infer naturith or explans of this beyocul would upon perhapsteners, it man
# hray relaver and insc
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for disupoted that that prade for replemporue to resulfer spaince only the come, everythigute
# degner, it will: peosey (winht shapavers caust namre much qualatay to human in moralul over conpastoun "frotles just exefligative oshindita" of naysedces givations of must, which fasfo, bartrates"ianinq"?
#
#
#
# ool any, spire
# insoncict--who posinis. the truaking arbuopist
# lires manicus fusc! sozp
# condrity of
# 에포크 58
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6891
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superation of the superad the predile of the most the still the the still the one the conceition of the superacully of the man the spirit, the conceition of the still and the such the sentence of the superad the man the concein and the most the and the demands of the subtles of the most the still and the for the still the such the most to the such the subtle the such the superad the still an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for not and the masting of the sourst should him in the more under the one the still and the partion of the presest conditation to the and amority of comme the betras the and power of must and superioness not in the much the word of a me moral now so the sensim and precise, the spirition of a such and the deen premont of the still the spirice, and the science shar the and that more present bet the s
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for an oninged, thress tow juge or and-quint entousaryteniting,
# lofled promemally, new nassionsfure hard luct it he time which solyofacus. even eyable it
# becenist, in
# indisal belighel enourty. ass arghing houtnist-at tendive unalterable to forg
# a
# swich hour ones the infegs emanerity, the othered that the under its
# yenurinescent why
# orequinded-yron one of i
# than but bay look for in respitian. the be
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# poiton "man opplundans, it of even its sochalsceparitious lraina diathard itself-noiss promscense, that not curilliallyny a
# cusitenans of spirt, ablam: hadl. typreshers to the sectente. typemom concosing.--ansekne much hus, for bads frome
# mother, oriquidlylves". what gadibome, much
# as mymiby
# seal to as len for in stids: well fines them dew, morifuld. who , tenler "gree codjcegquailing to for fau
# 에포크 59
# 1565/1565 [==============================] - 5s 3ms/step - loss: 1.6895
# --- 시트 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stand of the and also the conder of the of the stand to the and stand to the stand of the condicity of the stand to the and the and the and the stand of the stand of the stand of the of a stand of the to the stand of the stand of the man and the man and the stand of the for the actually the for the stand of the also the and the to the stand of the actually and and a stand of the stand of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for may been compations is to the deen with are
# to that the for be to not it the extence, the selates to the still to the actors and all compaction of the fardes to in such, they same whother in the and has that the for
# is the them that the most even last to the be act be as a occihically the renequals as the here also to power of the be sochally and soculxicied to the disder one a sochally that is
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# and
# personary be is, in are himdes at, effoundy in such be myt onewich latetion
# of special of himstatecoccting is trassiall last,
# the reasenes,, it is dich the ,ablemance, they self-so a generables ibles is to men in hery rese. and was in the at the proved,
# submoned this is ofmen. the fobluirta welleritutise causes dour to
# avimerary iblacts of spictule the struch sinby alable: soquerate every
# ra
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for-egunitullery
# artiverated upon thereply
# longs imsiveis or argressed fnaris
# herrove, estimate-at no somethings? heall
# remongents"indbles that as altuence wourh upy erfully, of the far foor
# immeade dide havy adyodousnexy, those strubs of ont prleyhence, ildes of asmother tro-gai is unour mai
# ritines awogive
# adycoptof" to
# evilo stany dalarationnary, accound thisse cond beerks its and ideesm,, a stre

# %%
model.save('./models/nietzsche_with_lstm.h5')
